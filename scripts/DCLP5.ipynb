# %% [markdown]
# # Process DCLP5 Dataset
#
# Source: [Jaeb diabetes datasets](https://public.jaeb.org/datasets/diabetes) - DCLP5_Dataset_2022-01-20.zip

# %%
import pandas as pd
import numpy as np
import os
import json
import datetime

data_source = '../../data_raw/DCLP5'
output_dir = '../../diax/DCLP5'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts')))
import dclp5

dclp5.process_all_dclp5(data_source, output_dir)

# %% [markdown]
# ### Command Line
# ```bash
# python scripts/dclp5.py --source ../../data_raw/DCLP5 --output ../../diax/DCLP5
# ```
