# %% [markdown]
# # IOBP2 Dataset
#
#
# Source: [Jaeb diabetes datasets](https://public.jaeb.org/datasets/diabetes) - IOBP2 RCT Public Dataset.zip

# %%
import pandas as pd
import numpy as np
import os
import json
import datetime

data_source = '../../data_raw/IOBP2_Public/Data Tables'
output_dir = '../../diax/IOBP2/'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts')))
import iobp2

iobp2.process_all_iobp2(data_source, output_dir)

# %% [markdown]
# ### Command Line
# ```bash
# python scripts/iobp2.py --source ../../data_raw/IOBP2_Public/Data Tables --output ../../diax/IOBP2
# ```
