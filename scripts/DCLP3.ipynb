# %% [markdown]
# # DCLP3
# Process DCLP3 dataset.
#
# Source: [Jaeb diabetes datasets](https://public.jaeb.org/datasets/diabetes) - DCLP3 Public Dataset - Release 3 - 2022-08-04.zip

# %%
import pandas as pd
import numpy as np
import os
import json
import datetime

data_source = '../../data_raw/DCLP3_public/Data Files'
output_dir = '../../diax/DCLP3/'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts')))
import dclp3

dclp3.process_all_dclp3(data_source, output_dir)

# %% [markdown]
# ### Command Line
# ```bash
# python scripts/dclp3.py --source ../../data_raw/DCLP3_public/Data Files --output ../../diax/DCLP3
# ```
