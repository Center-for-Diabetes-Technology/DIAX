# %% [markdown]
# # Process Loop Observational Dataset

# %%
import pandas as pd
import numpy as np
import os
import json
import datetime

data_source = "../../data_raw/Loop study public dataset 2023-01-31/Data Tables"
output_dir = "../../diax/LOOP/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
import os
import sys
import logging

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..", "scripts")))
import loop

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

loop.process_all_loop(data_source, output_dir)
# Out:
# 2026-03-19 15:19:39,487 - INFO - Processing subject 3
# 2026-03-19 15:19:43,514 - INFO - Processing subject 4
# 2026-03-19 15:19:47,675 - INFO - Processing subject 5
# 2026-03-19 15:19:51,918 - INFO - Processing subject 6
# 2026-03-19 15:19:56,290 - INFO - Processing subject 7
# 2026-03-19 15:19:59,588 - INFO - Processing subject 9
# 2026-03-19 15:20:04,558 - INFO - Processing subject 10
# 2026-03-19 15:20:09,227 - INFO - Processing subject 11
# 2026-03-19 15:20:13,909 - INFO - Processing subject 12
# 2026-03-19 15:20:18,548 - INFO - Processing subject 13
# 2026-03-19 15:20:23,100 - INFO - Processing subject 15
# 2026-03-19 15:20:26,705 - INFO - Processing subject 16
# 2026-03-19 15:20:30,393 - INFO - Processing subject 18
# 2026-03-19 15:20:34,677 - INFO - Processing subject 19
# 2026-03-19 15:20:39,418 - INFO - Processing subject 20
# 2026-03-19 15:20:43,641 - INFO - Processing subject 21
# 2026-03-19 15:20:46,771 - INFO - Processing subject 24
# ...

# %% [markdown]
# ### Command Line
# ```bash
# python scripts/loop.py --source "../../data_raw/Loop study public dataset 2023-01-31/Data Tables" --output ../../diax/LOOP
# ```
